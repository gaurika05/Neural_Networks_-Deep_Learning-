# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurika05/Neural_Networks_Deep_Learning/blob/main/tensor__basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles

# %%
data,target = make_circles(n_samples=1000,noise=0.03)# try to decrease noise 0.05->0.02

# %%
data[:5]
# Out:
# array([[-0.83348132, -0.44103161],
#        [-0.73998532,  0.32098297],
#        [-0.15654524, -0.92023939],
#        [ 0.82498771, -0.01085434],
#        [ 0.73707139,  0.24188708]])

# %%
target[:5]
# Out:
# array([0, 1, 0, 1, 1])

# %%
#data,target = make_circles(n_samples=1000,noise=0.03, random_state=10) to generate same random data

# %%
plt.scatter(data[:,0],data[:,1])
plt.show()

# %%
plt.scatter(data[:,0],data[:,1],c=target)# c means color one target color
plt.show()
